# %%
from datetime import datetime,timedelta
from os import path
import pandas as pd
import numpy as np
import requests
import schedule
import openpyxl
import random
import time
import sys

def DataToString(dataFrame):

    columns = list(dataFrame.columns)

    lengthColMax = 0

    for col in columns:
        if lengthColMax < len(col):
            lengthColMax = len(col)
    # definire la langueur de la plus grande cellule :
    for index, row in dataFrame.iterrows():
        for col in columns:
            if lengthColMax < len(row[col]):
                lengthColMax = len(row[col])+1

    # fixé une valeur paire de cette valeur: Val modulo 2 = 0
    if bool(lengthColMax % 2):
        lengthColMax += 1
#     print("Max Lenght : {} \n ".format(lengthColMax))

    StringData = ''
    lenghDelta = 0
    
    for col in columns:
        additionalSpaces2 = 0
        lenghDelta = lengthColMax - len(col)
        additionalSpaces = lenghDelta//2+bool(lenghDelta % 2)

        addedValue = additionalSpaces*" "+col+" "*additionalSpaces2

    #     while len(addedValue) != lengthColMax:
        if len(addedValue) > lengthColMax:
            additionalSpaces2 = additionalSpaces - 1
        elif len(addedValue) < lengthColMax:
            additionalSpaces2 = additionalSpaces + 1
        else:
            additionalSpaces2 = additionalSpaces

            addedValue = additionalSpaces*" "+col+" "*additionalSpaces2

        StringData += addedValue
#         print("Delta : ", lenghDelta, ' --> ', additionalSpaces, ' Total length: ', len(addedValue))
#         print(StringData)

    StringData += "\n"+(lengthColMax*len(columns)+2)*"-"+"\n"

    for index, row in dataFrame.iterrows():
        lenghDelta = 0
        for col in columns:
            lenghDelta = lengthColMax - len(row[col])
            additionalSpaces = lenghDelta//2+bool(lenghDelta % 2)

            if additionalSpaces*2+len(row[col]) > lengthColMax:
                additionalSpaces2 = additionalSpaces - 1
            elif additionalSpaces*2+len(row[col]) < lengthColMax:
                additionalSpaces2 = additionalSpaces + 1
            else:
                additionalSpaces2 = additionalSpaces

            addedValue = additionalSpaces*" "+row[col]+" "*additionalSpaces2+"|"
            StringData += addedValue
#             print("Delta : ", lenghDelta, ' --> ', additionalSpaces, ' Total length: ', len(addedValue))
#             print(StringData)

        StringData += "\n"
    return StringData

def telegram_bot_sendtext(bot_message, TELEGRAM_TOKEN, chat_id):
    bot_token = TELEGRAM_TOKEN
    bot_chatID = chat_id
    send_text = 'https://api.telegram.org/bot' + bot_token + '/sendMessage?chat_id=' + bot_chatID + '&parse_mode=Markdown&text=' + bot_message
    message_info = {"LogInfo":bot_message}
    print("LogInfo sended message : \n {}".format(message_info['LogInfo']))
    response = requests.get(send_text)
    return response.text

# %%
import schedule
import time

def telegram_bot_sendtext(bot_message, TELEGRAM_TOKEN, chat_id):
    bot_token = TELEGRAM_TOKEN
    bot_chatID = chat_id
    send_text = 'https://api.telegram.org/bot' + bot_token + '/sendMessage?chat_id=' + bot_chatID + '&parse_mode=Markdown&text=' + bot_message
    message_info = {"LogInfo":bot_message}
    print("LogInfo sended message : \n {}".format(message_info['LogInfo']))
    response = requests.get(send_text)
    return response.text

def generate_data():
    # lire la base de donnees dans ce niveau 
    ar = np.array([["LoaderCutting", random.randint(0,102)], ["Cutting-Cell-1",random.randint(0,882)], ["Cutting-Cell-2", random.randint(0,442)], ["Cutting-Cell-3", random.randint(400,1500)], ["Furnace-Exit", random.randint(0,2222)]])
    df = pd.DataFrame(ar, index = [' ', ' ', ' ', '', ''], columns = [' name ', ' value '])
    msg_entete = "Recap du : "+str(datetime.now()).split('.')[0]+"\n"
    bot_message = msg_entete+"\n"+DataToString(df)
    return bot_message
    
def job_Runners():
    # Test Runner:
    bot_message = generate_data()
    TELEGRAM_TOKEN = '5121400289:AAHRZKx2voyY3HSfHJi2bgsLdHqnKB_WpcY'
    # Individual 
    # chat_id = '1104376640'
    # Groupe
    chat_id = '-783940739'
    telegram_bot_sendtext(bot_message, TELEGRAM_TOKEN, chat_id)

# %%
def main():
    schedule.every(5).seconds.do(job_Runners)
    while True:
        schedule.run_pending()
#         time.sleep(1)
        
if __name__ == '__main__':
    main()
# Out:
# LogInfo sended message :
#  Recap du : 2022-03-21 14:13:55
#
#      name      value
# ------------------------------
#  LoaderCutting|      60      |
# Cutting-Cell-1|      415     |
# Cutting-Cell-2|      345     |
# Cutting-Cell-3|      616     |
#  Furnace-Exit |     1049     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:14:01
#
#      name      value
# ------------------------------
#  LoaderCutting|      42      |
# Cutting-Cell-1|      631     |
# Cutting-Cell-2|      137     |
# Cutting-Cell-3|     1422     |
#  Furnace-Exit |     2169     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:14:07
#
#      name      value
# ------------------------------
#  LoaderCutting|      78      |
# Cutting-Cell-1|      578     |
# Cutting-Cell-2|      412     |
# Cutting-Cell-3|      639     |
#  Furnace-Exit |     1134     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:14:13
#
#      name      value
# ------------------------------
#  LoaderCutting|      66      |
# Cutting-Cell-1|      141     |
# Cutting-Cell-2|      351     |
# Cutting-Cell-3|     1469     |
#  Furnace-Exit |      568     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:14:19
#
#      name      value
# ------------------------------
#  LoaderCutting|      33      |
# Cutting-Cell-1|      226     |
# Cutting-Cell-2|      288     |
# Cutting-Cell-3|      801     |
#  Furnace-Exit |     1826     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:14:25
#
#      name      value
# ------------------------------
#  LoaderCutting|      101     |
# Cutting-Cell-1|       3      |
# Cutting-Cell-2|       0      |
# Cutting-Cell-3|     1228     |
#  Furnace-Exit |      337     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:14:30
#
#      name      value
# ------------------------------
#  LoaderCutting|      10      |
# Cutting-Cell-1|      720     |
# Cutting-Cell-2|      150     |
# Cutting-Cell-3|     1466     |
#  Furnace-Exit |      708     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:14:37
#
#      name      value
# ------------------------------
#  LoaderCutting|      66      |
# Cutting-Cell-1|      866     |
# Cutting-Cell-2|      40      |
# Cutting-Cell-3|      927     |
#  Furnace-Exit |     1963     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:14:43
#
#      name      value
# ------------------------------
#  LoaderCutting|      34      |
# Cutting-Cell-1|      815     |
# Cutting-Cell-2|      211     |
# Cutting-Cell-3|      806     |
#  Furnace-Exit |     1866     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:14:49
#
#      name      value
# ------------------------------
#  LoaderCutting|      30      |
# Cutting-Cell-1|      432     |
# Cutting-Cell-2|      191     |
# Cutting-Cell-3|      696     |
#  Furnace-Exit |      593     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:14:55
#
#      name      value
# ------------------------------
#  LoaderCutting|      24      |
# Cutting-Cell-1|      822     |
# Cutting-Cell-2|      63      |
# Cutting-Cell-3|      626     |
#  Furnace-Exit |      567     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:15:01
#
#      name      value
# ------------------------------
#  LoaderCutting|      31      |
# Cutting-Cell-1|      309     |
# Cutting-Cell-2|      372     |
# Cutting-Cell-3|     1390     |
#  Furnace-Exit |     1729     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:15:07
#
#      name      value
# ------------------------------
#  LoaderCutting|      43      |
# Cutting-Cell-1|      317     |
# Cutting-Cell-2|      125     |
# Cutting-Cell-3|     1429     |
#  Furnace-Exit |      879     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:15:13
#
#      name      value
# ------------------------------
#  LoaderCutting|      90      |
# Cutting-Cell-1|      662     |
# Cutting-Cell-2|      341     |
# Cutting-Cell-3|     1459     |
#  Furnace-Exit |      883     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:15:19
#
#      name      value
# ------------------------------
#  LoaderCutting|      24      |
# Cutting-Cell-1|      178     |
# Cutting-Cell-2|      430     |
# Cutting-Cell-3|      787     |
#  Furnace-Exit |      949     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:15:24
#
#      name      value
# ------------------------------
#  LoaderCutting|      88      |
# Cutting-Cell-1|      676     |
# Cutting-Cell-2|      219     |
# Cutting-Cell-3|      532     |
#  Furnace-Exit |      947     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:15:30
#
#      name      value
# ------------------------------
#  LoaderCutting|      68      |
# Cutting-Cell-1|      177     |
# Cutting-Cell-2|      161     |
# Cutting-Cell-3|     1195     |
#  Furnace-Exit |      205     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:15:36
#
#      name      value
# ------------------------------
#  LoaderCutting|      31      |
# Cutting-Cell-1|      336     |
# Cutting-Cell-2|      295     |
# Cutting-Cell-3|     1325     |
#  Furnace-Exit |     1284     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:15:42
#
#      name      value
# ------------------------------
#  LoaderCutting|      43      |
# Cutting-Cell-1|      223     |
# Cutting-Cell-2|      333     |
# Cutting-Cell-3|     1378     |
#  Furnace-Exit |     1285     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:15:49
#
#      name      value
# ------------------------------
#  LoaderCutting|      32      |
# Cutting-Cell-1|      131     |
# Cutting-Cell-2|      154     |
# Cutting-Cell-3|     1434     |
#  Furnace-Exit |     1756     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:15:55
#
#      name      value
# ------------------------------
#  LoaderCutting|      22      |
# Cutting-Cell-1|      682     |
# Cutting-Cell-2|      250     |
# Cutting-Cell-3|     1486     |
#  Furnace-Exit |     1371     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:16:00
#
#      name      value
# ------------------------------
#  LoaderCutting|      96      |
# Cutting-Cell-1|      520     |
# Cutting-Cell-2|      169     |
# Cutting-Cell-3|      447     |
#  Furnace-Exit |      787     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:16:06
#
#      name      value
# ------------------------------
#  LoaderCutting|      25      |
# Cutting-Cell-1|      771     |
# Cutting-Cell-2|      422     |
# Cutting-Cell-3|     1434     |
#  Furnace-Exit |      54      |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:16:11
#
#      name      value
# ------------------------------
#  LoaderCutting|      10      |
# Cutting-Cell-1|      103     |
# Cutting-Cell-2|      291     |
# Cutting-Cell-3|     1226     |
#  Furnace-Exit |     1557     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:16:17
#
#      name      value
# ------------------------------
#  LoaderCutting|      37      |
# Cutting-Cell-1|      226     |
# Cutting-Cell-2|      244     |
# Cutting-Cell-3|     1132     |
#  Furnace-Exit |     1716     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:16:23
#
#      name      value
# ------------------------------
#  LoaderCutting|      28      |
# Cutting-Cell-1|      754     |
# Cutting-Cell-2|      146     |
# Cutting-Cell-3|      962     |
#  Furnace-Exit |     1282     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:16:28
#
#      name      value
# ------------------------------
#  LoaderCutting|      45      |
# Cutting-Cell-1|      247     |
# Cutting-Cell-2|       6      |
# Cutting-Cell-3|      742     |
#  Furnace-Exit |      985     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:16:34
#
#      name      value
# ------------------------------
#  LoaderCutting|       9      |
# Cutting-Cell-1|      782     |
# Cutting-Cell-2|      130     |
# Cutting-Cell-3|      697     |
#  Furnace-Exit |     1470     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:16:40
#
#      name      value
# ------------------------------
#  LoaderCutting|      88      |
# Cutting-Cell-1|      743     |
# Cutting-Cell-2|      227     |
# Cutting-Cell-3|     1407     |
#  Furnace-Exit |      376     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:16:45
#
#      name      value
# ------------------------------
#  LoaderCutting|      95      |
# Cutting-Cell-1|      820     |
# Cutting-Cell-2|      202     |
# Cutting-Cell-3|      690     |
#  Furnace-Exit |     1971     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:16:51
#
#      name      value
# ------------------------------
#  LoaderCutting|      90      |
# Cutting-Cell-1|      746     |
# Cutting-Cell-2|      50      |
# Cutting-Cell-3|      540     |
#  Furnace-Exit |     1172     |
# LogInfo sended message :
#  Recap du : 2022-03-21 14:16:56
#
#      name      value
# ------------------------------
#  LoaderCutting|      86      |
# Cutting-Cell-1|      97      |
# Cutting-Cell-2|      310     |
# Cutting-Cell-3|      965     |
#  Furnace-Exit |     1837     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:17:02
#
#      name      value
# ------------------------------
#  LoaderCutting|      15      |
# Cutting-Cell-1|      732     |
# Cutting-Cell-2|      275     |
# Cutting-Cell-3|      870     |
#  Furnace-Exit |     1071     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:17:07
#
#      name      value
# ------------------------------
#  LoaderCutting|      28      |
# Cutting-Cell-1|      363     |
# Cutting-Cell-2|      78      |
# Cutting-Cell-3|     1287     |
#  Furnace-Exit |     1314     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:17:13
#
#      name      value
# ------------------------------
#  LoaderCutting|      93      |
# Cutting-Cell-1|      272     |
# Cutting-Cell-2|      388     |
# Cutting-Cell-3|      916     |
#  Furnace-Exit |     2124     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:17:19
#
#      name      value
# ------------------------------
#  LoaderCutting|       0      |
# Cutting-Cell-1|      213     |
# Cutting-Cell-2|      268     |
# Cutting-Cell-3|      789     |
#  Furnace-Exit |      379     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:17:24
#
#      name      value
# ------------------------------
#  LoaderCutting|      98      |
# Cutting-Cell-1|      678     |
# Cutting-Cell-2|      261     |
# Cutting-Cell-3|     1435     |
#  Furnace-Exit |     1529     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:17:30
#
#      name      value
# ------------------------------
#  LoaderCutting|      32      |
# Cutting-Cell-1|      292     |
# Cutting-Cell-2|       6      |
# Cutting-Cell-3|     1178     |
#  Furnace-Exit |     1953     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:17:38
#
#      name      value
# ------------------------------
#  LoaderCutting|      19      |
# Cutting-Cell-1|      778     |
# Cutting-Cell-2|      19      |
# Cutting-Cell-3|      611     |
#  Furnace-Exit |     1480     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:17:44
#
#      name      value
# ------------------------------
#  LoaderCutting|      27      |
# Cutting-Cell-1|      223     |
# Cutting-Cell-2|      373     |
# Cutting-Cell-3|      628     |
#  Furnace-Exit |      800     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:17:50
#
#      name      value
# ------------------------------
#  LoaderCutting|      100     |
# Cutting-Cell-1|      597     |
# Cutting-Cell-2|      231     |
# Cutting-Cell-3|     1128     |
#  Furnace-Exit |     1337     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:17:56
#
#      name      value
# ------------------------------
#  LoaderCutting|      40      |
# Cutting-Cell-1|      392     |
# Cutting-Cell-2|      163     |
# Cutting-Cell-3|      798     |
#  Furnace-Exit |     1653     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:18:01
#
#      name      value
# ------------------------------
#  LoaderCutting|      88      |
# Cutting-Cell-1|      619     |
# Cutting-Cell-2|      395     |
# Cutting-Cell-3|     1314     |
#  Furnace-Exit |     2113     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:18:10
#
#      name      value
# ------------------------------
#  LoaderCutting|      52      |
# Cutting-Cell-1|      552     |
# Cutting-Cell-2|      402     |
# Cutting-Cell-3|      735     |
#  Furnace-Exit |     1705     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:18:20
#
#      name      value
# ------------------------------
#  LoaderCutting|      77      |
# Cutting-Cell-1|      317     |
# Cutting-Cell-2|      369     |
# Cutting-Cell-3|     1028     |
#  Furnace-Exit |      235     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:18:26
#
#      name      value
# ------------------------------
#  LoaderCutting|      32      |
# Cutting-Cell-1|      874     |
# Cutting-Cell-2|      217     |
# Cutting-Cell-3|     1184     |
#  Furnace-Exit |     1109     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:18:31
#
#      name      value
# ------------------------------
#  LoaderCutting|      59      |
# Cutting-Cell-1|      476     |
# Cutting-Cell-2|      409     |
# Cutting-Cell-3|      710     |
#  Furnace-Exit |      218     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:18:37
#
#      name      value
# ------------------------------
#  LoaderCutting|       6      |
# Cutting-Cell-1|      259     |
# Cutting-Cell-2|      393     |
# Cutting-Cell-3|      433     |
#  Furnace-Exit |     2068     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:18:43
#
#      name      value
# ------------------------------
#  LoaderCutting|      23      |
# Cutting-Cell-1|      278     |
# Cutting-Cell-2|      412     |
# Cutting-Cell-3|      680     |
#  Furnace-Exit |      843     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:18:48
#
#      name      value
# ------------------------------
#  LoaderCutting|       3      |
# Cutting-Cell-1|      477     |
# Cutting-Cell-2|      164     |
# Cutting-Cell-3|     1076     |
#  Furnace-Exit |      356     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:18:54
#
#      name      value
# ------------------------------
#  LoaderCutting|      75      |
# Cutting-Cell-1|      268     |
# Cutting-Cell-2|      298     |
# Cutting-Cell-3|      815     |
#  Furnace-Exit |     1081     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:19:02
#
#      name      value
# ------------------------------
#  LoaderCutting|      55      |
# Cutting-Cell-1|      789     |
# Cutting-Cell-2|      423     |
# Cutting-Cell-3|      781     |
#  Furnace-Exit |     1318     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:19:13
#
#      name      value
# ------------------------------
#  LoaderCutting|      45      |
# Cutting-Cell-1|      707     |
# Cutting-Cell-2|      407     |
# Cutting-Cell-3|      520     |
#  Furnace-Exit |     1168     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:19:22
#
#      name      value
# ------------------------------
#  LoaderCutting|       6      |
# Cutting-Cell-1|      255     |
# Cutting-Cell-2|      140     |
# Cutting-Cell-3|      525     |
#  Furnace-Exit |      139     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:19:29
#
#      name      value
# ------------------------------
#  LoaderCutting|       3      |
# Cutting-Cell-1|      859     |
# Cutting-Cell-2|      137     |
# Cutting-Cell-3|     1305     |
#  Furnace-Exit |     1866     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:19:45
#
#      name      value
# ------------------------------
#  LoaderCutting|      40      |
# Cutting-Cell-1|      451     |
# Cutting-Cell-2|      32      |
# Cutting-Cell-3|      863     |
#  Furnace-Exit |      405     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:19:51
#
#      name      value
# ------------------------------
#  LoaderCutting|      87      |
# Cutting-Cell-1|      512     |
# Cutting-Cell-2|      192     |
# Cutting-Cell-3|      489     |
#  Furnace-Exit |      533     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:19:57
#
#      name      value
# ------------------------------
#  LoaderCutting|      82      |
# Cutting-Cell-1|      430     |
# Cutting-Cell-2|      251     |
# Cutting-Cell-3|      941     |
#  Furnace-Exit |      273     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:20:03
#
#      name      value
# ------------------------------
#  LoaderCutting|      38      |
# Cutting-Cell-1|      567     |
# Cutting-Cell-2|      235     |
# Cutting-Cell-3|      573     |
#  Furnace-Exit |      563     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:20:08
#
#      name      value
# ------------------------------
#  LoaderCutting|      52      |
# Cutting-Cell-1|      91      |
# Cutting-Cell-2|      44      |
# Cutting-Cell-3|      832     |
#  Furnace-Exit |     1783     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:20:18
#
#      name      value
# ------------------------------
#  LoaderCutting|      72      |
# Cutting-Cell-1|      261     |
# Cutting-Cell-2|      130     |
# Cutting-Cell-3|     1271     |
#  Furnace-Exit |      55      |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:20:32
#
#      name      value
# ------------------------------
#  LoaderCutting|      21      |
# Cutting-Cell-1|      33      |
# Cutting-Cell-2|      129     |
# Cutting-Cell-3|      780     |
#  Furnace-Exit |      187     |
# LogInfo sended message :
#  Recap du : 2022-03-21 14:20:39
#
#      name      value
# ------------------------------
#  LoaderCutting|      92      |
# Cutting-Cell-1|      856     |
# Cutting-Cell-2|      420     |
# Cutting-Cell-3|      942     |
#  Furnace-Exit |     1558     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:20:56
#
#      name      value
# ------------------------------
#  LoaderCutting|      84      |
# Cutting-Cell-1|      519     |
# Cutting-Cell-2|      243     |
# Cutting-Cell-3|      425     |
#  Furnace-Exit |     2024     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:21:10
#
#      name      value
# ------------------------------
#  LoaderCutting|      13      |
# Cutting-Cell-1|      333     |
# Cutting-Cell-2|      225     |
# Cutting-Cell-3|      751     |
#  Furnace-Exit |     1173     |
#
# LogInfo sended message :
#  Recap du : 2022-03-21 14:21:21
#
#      name      value
# ------------------------------
#  LoaderCutting|      69      |
# Cutting-Cell-1|      61      |
# Cutting-Cell-2|      151     |
# Cutting-Cell-3|      974     |
#  Furnace-Exit |     1556     |

# %%
#     schedule.every().day.at("00:00").do(telegram_bot_sendtext, generate_data(), TELEGRAM_TOKEN, chat_id)
#     schedule.every().day.at("08:00").do(telegram_bot_sendtext, generate_data(), TELEGRAM_TOKEN= TELEGRAM_TOKEN, chat_id= chat_id)
#     schedule.every().day.at("16:00").do(telegram_bot_sendtext, generate_data(), TELEGRAM_TOKEN= TELEGRAM_TOKEN, chat_id= chat_id)
